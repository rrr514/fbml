# %%
import pandas as pd

# Train with 2022-2023 data, Test with 2023-2024 data
df_22 = pd.read_csv('data/2022playerstats_WR.csv')
df_23 = pd.read_csv('data/2023playerstats_WR.csv')
df_24 = pd.read_csv('data/2024playerstats_WR.csv')
print(df_22.head())
print(df_23.head())
print(df_24.head())
# Out:
#    Rk            Player Team FantPos  Age  GamesPlayed  GamesStarted  PassCmp  \
# 0   5  Justin Jefferson  MIN      WR   23           17            17        2
# 1   8     Davante Adams  LVR      WR   30           17            17        0
# 2  11       Tyreek Hill  MIA      WR   28           17            17        0
# 3  13        A.J. Brown  PHI      WR   25           17            16        0
# 4  14      Stefon Diggs  BUF      WR   29           16            16        0
#
#    PassAtt  PassYds  ...  Receiving_YAC/R  Receiving_ADOT  Receiving_BrkTkl  \
# 0        2       34  ...              4.9            10.1               6.0
# 1        0        0  ...              4.9            11.8               9.0
# 2        0        0  ...              4.1            12.2               5.0
# 3        0        0  ...              6.2            12.1               7.0
# 4        0        0  ...              3.9            11.2               2.0
#
#    Receiving_Rec/Br  Receiving_Drop  Receiving_Drop%  Receiving_Int  \
# 0              21.3             5.0              2.7            5.0
# 1              11.1             7.0              3.9            6.0
# 2              23.8             8.0              4.7            6.0
# 3              12.6             5.0              3.4            3.0
# 4              54.0             8.0              5.2            1.0
#
#    Receiving_Rat                       Awards  Year
# 0          104.2   PB,AP-1,AP MVP-5,AP OPoY-1  2022
# 1           95.5                      PB,AP-1  2022
# 2          101.3   PB,AP-1,AP MVP-9,AP OPoY-4  2022
# 3          112.3  PB,AP-2,AP MVP-9,AP OPoY-11  2022
# 4          120.3                      PB,AP-2  2022
#
# [5 rows x 95 columns]
#    Rk             Player Team FantPos  Age  GamesPlayed  GamesStarted  \
# 0   2        CeeDee Lamb  DAL      WR   24           17            17
# 1   4        Tyreek Hill  MIA      WR   29           16            16
# 2   7  Amon-Ra St. Brown  DET      WR   24           16            16
# 3   9         Mike Evans  TAM      WR   30           17            17
# 4  14         Puka Nacua  LAR      WR   22           17            17
#
#    PassCmp  PassAtt  PassYds  ...  Receiving_YAC/R  Receiving_ADOT  \
# 0        0        0        0  ...              5.0             9.5
# 1        0        0        0  ...              5.5            10.8
# 2        0        0        0  ...              5.6             7.8
# 3        0        0        0  ...              4.1            14.0
# 4        0        0        0  ...              6.0             9.1
#
#    Receiving_BrkTkl  Receiving_Rec/Br  Receiving_Drop  Receiving_Drop%  \
# 0              11.0              12.3             6.0              3.3
# 1              12.0               9.9            12.0              7.0
# 2              10.0              11.9             8.0              4.9
# 3               2.0              39.5             7.0              5.1
# 4               7.0              15.0            13.0              8.1
#
#    Receiving_Int  Receiving_Rat                      Awards  Year
# 0            1.0          124.3           PB,AP-1,AP OPoY-3  2023
# 1            5.0          117.1  PB,AP-1,AP MVP-6,AP OPoY-2  2023
# 2            3.0          113.7                     PB,AP-1  2023
# 3            3.0          111.6                     PB,AP-2  2023
# 4            3.0          100.2           PB,AP-2,AP ORoY-2  2023
#
# [5 rows x 95 columns]
#    Rk             Player Team FantPos  Age  GamesPlayed  GamesStarted  \
# 0   5      Ja'Marr Chase  CIN      WR   24           17            16
# 1  12   Justin Jefferson  MIN      WR   25           17            17
# 2  18  Amon-Ra St. Brown  DET      WR   25           17            17
# 3  19       Brian Thomas  JAX      WR   22           17            16
# 4  23     Terry McLaurin  WAS      WR   29           17            17
#
#    PassCmp  PassAtt  PassYds  ...  Receiving_YAC/R  Receiving_ADOT  \
# 0        0        0        0  ...              6.2             8.7
# 1        1        1       22  ...              4.7            10.9
# 2        1        1        7  ...              3.6             7.7
# 3        0        0        0  ...              6.5            11.4
# 4        0        0        0  ...              3.6            13.4
#
#    Receiving_BrkTkl  Receiving_Rec/Br  Receiving_Drop  Receiving_Drop%  \
# 0              11.0              11.5             9.0              5.1
# 1               5.0              20.6             5.0              3.2
# 2               3.0              38.3             4.0              2.8
# 3               0.0               NaN             7.0              5.3
# 4               2.0              41.0             4.0              3.4
#
#    Receiving_Int  Receiving_Rat                      Awards  Year
# 0            7.0          118.9  PB,AP-1,AP MVP-8,AP OPoY-3  2024
# 1            5.0          107.4           PB,AP-1,AP OPoY-7  2024
# 2            1.0          129.4          PB,AP-1,AP OPoY-11  2024
# 3            5.0          106.2                PB,AP ORoY-4  2024
# 4            1.0          133.0                     PB,AP-2  2024
#
# [5 rows x 95 columns]

# %% [markdown]
# # WR Model:
# - targets per game
# - recs per game
# - rec yards per game
# - rec tds per game

# %%
from helpers import compute_wr_features

# %%
# Compute the features needed
compute_wr_features(df_22)
compute_wr_features(df_23)

print(df_22.head())
print(df_23.head())
# Out:
#    Rk            Player Team FantPos  Age  GamesPlayed  GamesStarted  PassCmp  \
# 0   5  Justin Jefferson  MIN      WR   23           17            17        2
# 1   8     Davante Adams  LVR      WR   30           17            17        0
# 2  11       Tyreek Hill  MIA      WR   28           17            17        0
# 3  13        A.J. Brown  PHI      WR   25           17            16        0
# 4  14      Stefon Diggs  BUF      WR   29           16            16        0
#
#    PassAtt  PassYds  ...  Receiving_Drop  Receiving_Drop%  Receiving_Int  \
# 0        2       34  ...             5.0              2.7            5.0
# 1        0        0  ...             7.0              3.9            6.0
# 2        0        0  ...             8.0              4.7            6.0
# 3        0        0  ...             5.0              3.4            3.0
# 4        0        0  ...             8.0              5.2            1.0
#
#    Receiving_Rat                       Awards  Year  TargetsPerGame  \
# 0          104.2   PB,AP-1,AP MVP-5,AP OPoY-1  2022       10.823529
# 1           95.5                      PB,AP-1  2022       10.588235
# 2          101.3   PB,AP-1,AP MVP-9,AP OPoY-4  2022       10.000000
# 3          112.3  PB,AP-2,AP MVP-9,AP OPoY-11  2022        8.529412
# 4          120.3                      PB,AP-2  2022        9.625000
#
#    RecsPerGame  RecYdsPerGame  RecTDsPerGame
# 0     7.529412     106.411765       0.470588
# 1     5.882353      89.176471       0.823529
# 2     7.000000     100.588235       0.411765
# 3     5.176471      88.000000       0.647059
# 4     6.750000      89.312500       0.687500
#
# [5 rows x 99 columns]
#    Rk             Player Team FantPos  Age  GamesPlayed  GamesStarted  \
# 0   2        CeeDee Lamb  DAL      WR   24           17            17
# 1   4        Tyreek Hill  MIA      WR   29           16            16
# 2   7  Amon-Ra St. Brown  DET      WR   24           16            16
# 3   9         Mike Evans  TAM      WR   30           17            17
# 4  14         Puka Nacua  LAR      WR   22           17            17
#
#    PassCmp  PassAtt  PassYds  ...  Receiving_Drop  Receiving_Drop%  \
# 0        0        0        0  ...             6.0              3.3
# 1        0        0        0  ...            12.0              7.0
# 2        0        0        0  ...             8.0              4.9
# 3        0        0        0  ...             7.0              5.1
# 4        0        0        0  ...            13.0              8.1
#
#    Receiving_Int  Receiving_Rat                      Awards  Year  \
# 0            1.0          124.3           PB,AP-1,AP OPoY-3  2023
# 1            5.0          117.1  PB,AP-1,AP MVP-6,AP OPoY-2  2023
# 2            3.0          113.7                     PB,AP-1  2023
# 3            3.0          111.6                     PB,AP-2  2023
# 4            3.0          100.2           PB,AP-2,AP ORoY-2  2023
#
#    TargetsPerGame  RecsPerGame  RecYdsPerGame  RecTDsPerGame
# 0       10.647059     7.941176     102.882353       0.705882
# 1       10.687500     7.437500     112.437500       0.812500
# 2       10.250000     7.437500      94.687500       0.625000
# 3        8.000000     4.647059      73.823529       0.764706
# 4        9.411765     6.176471      87.411765       0.352941
#
# [5 rows x 99 columns]

# %%
# Keep only the features we want
features = [
    'TargetsPerGame',
    'RecsPerGame',
    'RecYdsPerGame',
    'RecTDsPerGame'
]

# Merge the data frames to remove players that are not in both
df_22_23_merged = df_22.merge(df_23, on='Player', how='inner', suffixes=('', '_23'))
df_23_24_merged = df_23.merge(df_24, on='Player', how='inner', suffixes=('', '_24'))

y_test = df_23_24_merged['FantasyPtsPPR_24']
y_train = df_22_23_merged['FantasyPtsPPR_23']

X_test = df_23_24_merged[features]
X_train = df_22_23_merged[features]

print(y_test.head())
print(X_test.head())
print(y_train.head())
print(X_train.head())
# Out:
# 0    263.4
# 1    218.2
# 2    316.2
# 3    240.4
# 4    206.6
# Name: FantasyPtsPPR_24, dtype: float64
#    TargetsPerGame  RecsPerGame  RecYdsPerGame  RecTDsPerGame
# 0       10.647059     7.941176     102.882353       0.705882
# 1       10.687500     7.437500     112.437500       0.812500
# 2       10.250000     7.437500      94.687500       0.625000
# 3        8.000000     4.647059      73.823529       0.764706
# 4        9.411765     6.176471      87.411765       0.352941
# 0    202.2
# 1    265.4
# 2    376.4
# 3    289.6
# 4    273.8
# Name: FantasyPtsPPR_23, dtype: float64
#    TargetsPerGame  RecsPerGame  RecYdsPerGame  RecTDsPerGame
# 0       10.823529     7.529412     106.411765       0.470588
# 1       10.588235     5.882353      89.176471       0.823529
# 2       10.000000     7.000000     100.588235       0.411765
# 3        8.529412     5.176471      88.000000       0.647059
# 4        9.625000     6.750000      89.312500       0.687500

# %%
# Normalize the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

print(X_train[:5])
print(X_test[:5])
# Out:
# [[2.3611031  2.54970558 2.99189454 1.47066387]
#  [2.28184403 1.72497364 2.31620055 3.24644823]
#  [2.08369635 2.28461318 2.76358838 1.17469981]
#  [1.58832716 1.3715171  2.27007809 2.35855605]
#  [1.95737721 2.15943065 2.32153346 2.56203134]]
# [[2.3016588  2.75588857 2.85352717 2.65452011]
#  [2.31528145 2.5036826  3.22812799 3.19095497]
#  [2.16790912 2.5036826  2.53225543 2.24756953]
#  [1.40999425 1.10642469 1.71430249 2.95048417]
#  [1.88554868 1.87224721 2.24701686 0.87873575]]

# %%
from helpers import print_diagnostics
print_diagnostics(X_train, X_test, features, y_train, y_test)
# Out:
# Training samples: 181
# Testing samples: 184
# Features: 4
# Samples per feature: 45.2
# Training target stats: mean=81.1, std=89.3
# Testing target stats: mean=84.1, std=85.4

# %%
# Train and evaluate
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(X_train, y_train)

train_preds = model.predict(X_train)
preds = model.predict(X_test)

from helpers import evaluate_model
evaluate_model(y_train, train_preds, y_test, preds)
# Out:
# Training RMSE: 49.01344761079798
# Training R^2: 0.6969570189674076
# Training MAE: 36.58444884666653
# Testing RMSE: 60.109931504491705
# Testing R^2: 0.5019045091869618
# Testing MAE: 45.050065182237184

# %%
print(preds[:5])
print(y_test.head())
# Out:
# [276.15623519 306.77244593 257.17538846 208.81184231 247.68235331]
# 0    263.4
# 1    218.2
# 2    316.2
# 3    240.4
# 4    206.6
# Name: FantasyPtsPPR_24, dtype: float64

# %%
# Model coefficients
print("Intercept:", model.intercept_)
print("Feature Coefficients:")
for feat, coef in zip(features, model.coef_):
    print(f"{feat}: {coef:.4f}")
# Out:
# Intercept: 81.10220994475138
# Feature Coefficients:
# TargetsPerGame: 32.6678
# RecsPerGame: -24.3558
# RecYdsPerGame: 68.0933
# RecTDsPerGame: -2.7576

# %%
from helpers import compute_rank_squared_error, build_results_df

# rank_squared_error = compute_rank_squared_error(y_test, preds, df_23_24_merged['Player'], True)
results = build_results_df(y_test, preds, df_23_24_merged['Player'])
rank_squared_error = compute_rank_squared_error(results)

print(results.to_string())
print("Testing Rank Squared Error:", rank_squared_error)
# Out:
#                        Player  Actual   Predicted  ActualRank  PredictedRank  RankError
# 0                 CeeDee Lamb   263.4  276.156235           6              3         -3
# 1                 Tyreek Hill   218.2  306.772446          15              1        -14
# 2           Amon-Ra St. Brown   316.2  257.175388           3              5          2
# 3                  Mike Evans   240.4  208.811842          11             14          3
# 4                  Puka Nacua   206.6  247.682353          23              6        -17
# 5                  D.J. Moore   238.1  217.813404          13             12         -1
# 6                  A.J. Brown   216.9  240.143239          17              8         -9
# 7                Deebo Samuel   153.6  159.770274          39             35         -4
# 8                Nico Collins   210.6  229.334061          20              9        -11
# 9               Brandon Aiyuk    62.4  223.872790          91             11        -80
# 10               Keenan Allen   184.4  264.418984          29              4        -25
# 11               Stefon Diggs   121.9  197.034694          56             20        -36
# 12              Ja'Marr Chase   403.0  211.304891           1             13         12
# 13              Davante Adams   241.3  203.489617           9             16          7
# 14               D.K. Metcalf   191.2  201.453478          28             18        -10
# 15               Amari Cooper   122.7  244.187486          55              7        -48
# 16              Calvin Ridley   199.2  177.514323          25             26          1
# 17                Jayden Reed   197.0  132.226347          26             46         20
# 18             Jordan Addison   212.5  145.573508          18             40         22
# 19            DeAndre Hopkins   147.0  186.133478          43             23        -20
# 20              Jakobi Meyers   218.0  137.479713          16             43         27
# 21              DeVonta Smith   199.4  178.064251          24             25          1
# 22             George Pickens   164.4  189.341691          37             22        -15
# 23                Chris Olave    76.7  202.617239          81             17        -64
# 24        Michael Pittman Jr.   165.8  203.933575          36             15        -21
# 25           Justin Jefferson   317.5  297.869917           2              2          0
# 135         Xavier Hutchinson    23.7   12.973853         115            136         21
# 136             Charlie Jones     5.5    7.762463         150            148         -2
# 137      Terrace Marshall Jr.     7.1   46.819798         143            101        -42
# 138             Ben Skowronek    11.9    2.564517         134            155         21
# 139           Tyquan Thornton     8.7   28.485866         140            115        -25
# 140      Laviska Shenault Jr.    10.7    9.520222         137            144          7
# 141            Mecole Hardman    33.2   28.459677         109            116          7
# 142           Parris Campbell    15.0   18.557326         124            128          4
# 143          Sterling Shepard    80.3    8.216350          78            146         68
# 144                 Tim Jones     7.1    7.781866         143            147          4
# 145              Chris Conley    13.6   17.692590         131            130         -1
# 146               Simi Fehoko    16.6   -5.684625         122            169         47
# 147             Tyler Johnson    61.1    7.090737          92            150         58
# 148           Velus Jones Jr.     0.9   -3.180676         164            164          0
# 149             Tylan Wallace    36.3   -5.450310         106            168         62
# 150              Jalen Brooks    35.7   14.373980         107            135         28
# 151            DeAndre Carter    14.2   -1.226118         128            160         32
# 152             Rakim Jarrett    21.4   12.030795         118            140         22
# 153     Equanimeous St. Brown     0.0   15.353498         165            134        -31
# 154               Justyn Ross     0.0    9.923818         165            143        -22
# 155              Elijah Cooks     0.0    3.084982         165            153        -12
# 156             Britain Covey    10.4   -0.926730         138            159         21
# 157            Devin Duvernay    19.2   -1.449866         119            161         42
# 158          Trishton Jackson     0.0   -2.776025         165            163         -2
# 159              Jalen Nailor   103.0    8.797186          68            145         77
# 160               Steven Sims    -2.0   12.042712         183            139        -44
# 161            Kayshon Boutte   121.9   11.659910          56            141         85
# 162             Erik Ezukanma     0.0   -3.509813         165            165          0
# 163               Zach Pascal     0.0    2.916749         165            154        -11
# 164          Laquon Treadwell     0.0    3.693979         165            151        -14
# 165          D'Wayne Eskridge     7.4   -6.260860         142            170         28
# 166            Collin Johnson     1.6    0.379220         160            157         -3
# 167              Mason Kinsey     3.7   -6.540956         154            171         17
# 168             Cody Thompson     0.0   -5.368500         165            167          2
# 169           Austin Trammell     4.0   -2.407966         153            162          9
# 170               Chris Blair     2.7   -9.011907         157            174         17
# 171          Marquez Callaway     0.0   -9.011907         165            174          9
# 172             Irvin Charles     0.0   -8.094891         165            173          8
# 173               Dan Chisena     6.7   -9.011907         145            174         29
# 174             Jaelon Darden     1.6   -9.011907         160            174         14
# 175           Dez Fitzpatrick     0.0   -9.011907         165            174          9
# 176                Tay Martin    11.9   -9.011907         134            174         40
# 177               Ryan Miller    36.8   -9.011907         105            174         69
# 178                 DJ Turner    47.1   -9.011907         100            174         74
# 179       Montrell Washington     0.0   -9.011907         165            174          9
# 180        Kristian Wilkerson     9.8   -9.011907         139            174         35
# 181              Dareke Young     0.0   -9.011907         165            174          9
# 182              James Proche     3.1   -3.509813         156            165          9
# 183              Trent Taylor     2.1   -7.717296         158            172         14
# Testing Rank Squared Error: 259570

# %%
import joblib
import os

model_package = {
    'model': model,
    'scaler': scaler,
    'features': features
}

os.makedirs('models', exist_ok=True)
filepath = os.path.join('models', 'wr_model.joblib')

joblib.dump(model_package, filepath)

print("Model saved as 'wr_model.joblib'")
# Out:
# Model saved as 'wr_model.joblib'
