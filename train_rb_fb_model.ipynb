# %%
import pandas as pd

# Train with 2022-2023 data, Test with 2023-2024 data
df_22 = pd.read_csv('data/2022playerstats_RB_FB.csv')
df_23 = pd.read_csv('data/2023playerstats_RB_FB.csv')
df_24 = pd.read_csv('data/2024playerstats_RB_FB.csv')
print(df_22.head())
print(df_23.head())
print(df_24.head())
# Out:
#            Player FantPos  Age  GamesPlayed  GamesStarted  PassCmp  PassAtt  \
# 0   Kyle Juszczyk      FB   31           16            12        0        0
# 1     Alec Ingold      FB   26           17            14        0        0
# 2        C.J. Ham      FB   29           17             4        0        0
# 3      Derek Watt      FB   30           17             3        0        0
# 4  Zander Horvath      FB   24           15             2        0        0
#
#    PassYds  PassTD  PassInt  ...  Team_NWE  Team_NYG  Team_NYJ  Team_PHI  \
# 0        0       0        0  ...     False     False     False     False
# 1        0       0        0  ...     False     False     False     False
# 2        0       0        0  ...     False     False     False     False
# 3        0       0        0  ...     False     False     False     False
# 4        0       0        0  ...     False     False     False     False
#
#    Team_PIT  Team_SEA  Team_SFO  Team_TAM  Team_TEN  Team_WAS
# 0     False     False      True     False     False     False
# 1     False     False     False     False     False     False
# 2     False     False     False     False     False     False
# 3      True     False     False     False     False     False
# 4     False     False     False     False     False     False
#
# [5 rows x 67 columns]
#            Player FantPos  Age  GamesPlayed  GamesStarted  PassCmp  PassAtt  \
# 0     Andrew Beck      FB   27           15            12        0        0
# 1   Kyle Juszczyk      FB   32           17            16        0        0
# 2     Alec Ingold      FB   27           17            13        0        0
# 3  Patrick Ricard      FB   29           17             9        0        0
# 4     Nick Bawden      FB   27           16             2        0        0
#
#    PassYds  PassTD  PassInt  ...  Team_NWE  Team_NYG  Team_NYJ  Team_PHI  \
# 0        0       0        0  ...     False     False     False     False
# 1        0       0        0  ...     False     False     False     False
# 2        0       0        0  ...     False     False     False     False
# 3        0       0        0  ...     False     False     False     False
# 4        0       0        0  ...     False     False      True     False
#
#    Team_PIT  Team_SEA  Team_SFO  Team_TAM  Team_TEN  Team_WAS
# 0     False     False     False     False     False     False
# 1     False     False      True     False     False     False
# 2     False     False     False     False     False     False
# 3     False     False     False     False     False     False
# 4     False     False     False     False     False     False
#
# [5 rows x 67 columns]
#            Player FantPos  Age  GamesPlayed  GamesStarted  PassCmp  PassAtt  \
# 0   Kyle Juszczyk      FB   33           17            15      0.0      0.0
# 1  Michael Burton      FB   32           17             2      0.0      0.0
# 2     Alec Ingold      FB   28           15            10      0.0      0.0
# 3  Patrick Ricard      FB   30           17             6      0.0      0.0
# 4        C.J. Ham      FB   31           17             3      0.0      0.0
#
#    PassYds  PassTD  PassInt  ...  Team_NWE  Team_NYG  Team_NYJ  Team_PHI  \
# 0      0.0     0.0      0.0  ...     False     False     False     False
# 1      0.0     0.0      0.0  ...     False     False     False     False
# 2      0.0     0.0      0.0  ...     False     False     False     False
# 3      0.0     0.0      0.0  ...     False     False     False     False
# 4      0.0     0.0      0.0  ...     False     False     False     False
#
#    Team_PIT  Team_SEA  Team_SFO  Team_TAM  Team_TEN  Team_WAS
# 0     False     False      True     False     False     False
# 1     False     False     False     False     False     False
# 2     False     False     False     False     False     False
# 3     False     False     False     False     False     False
# 4     False     False     False     False     False     False
#
# [5 rows x 67 columns]

# %% [markdown]
# # RB Model:
# - rush attempts per game
# - rush yards per game
# - rush tds per game
# - targets per game
# - recs per game
# - rec yards per game
# - rec tds per game

# %%
from helpers import compute_rb_fb_features

# %%
# Compute the features needed
compute_rb_fb_features(df_22)
compute_rb_fb_features(df_23)

print(df_22.head())
print(df_23.head())
# Out:
#            Player FantPos  Age  GamesPlayed  GamesStarted  PassCmp  PassAtt  \
# 0   Kyle Juszczyk      FB   31           16            12        0        0
# 1     Alec Ingold      FB   26           17            14        0        0
# 2        C.J. Ham      FB   29           17             4        0        0
# 3      Derek Watt      FB   30           17             3        0        0
# 4  Zander Horvath      FB   24           15             2        0        0
#
#    PassYds  PassTD  PassInt  ...  Team_TAM  Team_TEN  Team_WAS  \
# 0        0       0        0  ...     False     False     False
# 1        0       0        0  ...     False     False     False
# 2        0       0        0  ...     False     False     False
# 3        0       0        0  ...     False     False     False
# 4        0       0        0  ...     False     False     False
#
#    RushAttPerGame  RushYdsPerGame  RushTDsPerGame  TargetsPerGame  \
# 0        0.437500        1.625000        0.062500        1.437500
# 1        0.352941        0.470588        0.058824        1.352941
# 2        0.235294        0.411765        0.117647        0.705882
# 3        0.529412        1.235294        0.058824        0.294118
# 4        0.266667        0.533333        0.000000        0.533333
#
#    RecsPerGame  RecYdsPerGame  RecTDsPerGame
# 0     1.187500      12.500000       0.062500
# 1     0.882353       6.176471       0.058824
# 2     0.588235       5.058824       0.000000
# 3     0.294118       0.647059       0.058824
# 4     0.333333       0.533333       0.133333
#
# [5 rows x 74 columns]
#            Player FantPos  Age  GamesPlayed  GamesStarted  PassCmp  PassAtt  \
# 0     Andrew Beck      FB   27           15            12        0        0
# 1   Kyle Juszczyk      FB   32           17            16        0        0
# 2     Alec Ingold      FB   27           17            13        0        0
# 3  Patrick Ricard      FB   29           17             9        0        0
# 4     Nick Bawden      FB   27           16             2        0        0
#
#    PassYds  PassTD  PassInt  ...  Team_TAM  Team_TEN  Team_WAS  \
# 0        0       0        0  ...     False     False     False
# 1        0       0        0  ...     False     False     False
# 2        0       0        0  ...     False     False     False
# 3        0       0        0  ...     False     False     False
# 4        0       0        0  ...     False     False     False
#
#    RushAttPerGame  RushYdsPerGame  RushTDsPerGame  TargetsPerGame  \
# 0        0.333333        0.200000        0.066667        0.866667
# 1        0.294118        0.352941        0.000000        1.000000
# 2        0.117647        0.000000        0.000000        0.941176
# 3        0.000000        0.000000        0.000000        0.411765
# 4        0.125000        0.250000        0.062500        0.187500
#
#    RecsPerGame  RecYdsPerGame  RecTDsPerGame
# 0     0.733333       3.666667       0.133333
# 1     0.823529       7.000000       0.117647
# 2     0.764706       7.000000       0.000000
# 3     0.294118       3.058824       0.058824
# 4     0.187500       1.312500       0.000000
#
# [5 rows x 74 columns]

# %%
# Keep only the features we want
features = [
    'RushAttPerGame',
    'RushYdsPerGame',
    'RushTDsPerGame',
    'TargetsPerGame',
    'RecsPerGame',
    'RecYdsPerGame',
    'RecTDsPerGame'
]

# Merge the data frames to remove players that are not in both
df_22_23_merged = df_22.merge(df_23, on='Player', how='inner', suffixes=('', '_23'))
df_23_24_merged = df_23.merge(df_24, on='Player', how='inner', suffixes=('', '_24'))

y_test = df_23_24_merged['FantasyPtsPPR_24']
y_train = df_22_23_merged['FantasyPtsPPR_23']

X_test = df_23_24_merged[features]
X_train = df_22_23_merged[features]

print(y_test.head())
print(X_test.head())
print(y_train.head())
print(X_train.head())
# Out:
# 0    57.6
# 1    26.3
# 2    17.2
# 3    29.3
# 4     0.0
# Name: FantasyPtsPPR_24, dtype: float64
#    RushAttPerGame  RushYdsPerGame  RushTDsPerGame  TargetsPerGame  \
# 0        0.294118        0.352941             0.0        1.000000
# 1        0.117647        0.000000             0.0        0.941176
# 2        0.000000        0.000000             0.0        0.411765
# 3        0.411765        0.529412             0.0        0.176471
# 4        0.500000        1.625000             0.0        0.375000
#
#    RecsPerGame  RecYdsPerGame  RecTDsPerGame
# 0     0.823529       7.000000       0.117647
# 1     0.764706       7.000000       0.000000
# 2     0.294118       3.058824       0.058824
# 3     0.176471       0.470588       0.000000
# 4     0.187500       0.125000       0.000000
# 0    38.5
# 1    24.9
# 2    10.2
# 3     1.3
# 4     1.2
# Name: FantasyPtsPPR_23, dtype: float64
#    RushAttPerGame  RushYdsPerGame  RushTDsPerGame  TargetsPerGame  \
# 0        0.437500        1.625000        0.062500        1.437500
# 1        0.352941        0.470588        0.058824        1.352941
# 2        0.235294        0.411765        0.117647        0.705882
# 3        0.000000        0.000000        0.000000        0.666667
# 4        0.000000        0.000000        0.000000        0.600000
#
#    RecsPerGame  RecYdsPerGame  RecTDsPerGame
# 0
#  [ 1.29869121  1.45902624  4.5618002   0.29215327  0.30877472  0.24284868
#    1.8777303 ]
#  [ 1.60541334  1.15404035  2.07476162  1.65875058  1.72191347  1.9858031
#    0.17884378]
#  [ 2.17542793  2.49896373  3.66223305  1.47273461  1.11855086  0.8297619
#    2.47941927]
#  [ 1.73773816  1.5030765   2.33934019  0.28223241  0.29289676  0.34119064
#   -0.5290256 ]
#  [ 1.50362502  1.21111544  1.54560447  1.32392184  1.43611012  1.35808842
#    1.59458254]
#  [ 1.15754474  1.1233076   0.48729019  2.47722085  2.57932349  2.70767498
#    2.30245193]
#  [ 1.6563075   1.11452682  0.75186876  1.547141    2.00771681  2.44403482
#    1.59458254]
#  [ 1.59450745  1.64686184  3.34095907  0.0271248  -0.11539373 -0.11031556
#   -0.5290256 ]
#  [ 0.98721896  1.29233769  2.16295448  1.93653443  1.76637176  1.24593673
#    0.27322637]
#  [ 1.30004839  1.40429269 -0.30644553  0.9518899   1.055039    1.79121155
#    2.30245193]]

# %%
from helpers import print_diagnostics
print_diagnostics(X_train, X_test, features, y_train, y_test)
# Out:
# Training samples: 127
# Testing samples: 114
# Features: 7
# Samples per feature: 18.1
# Training target stats: mean=79.2, std=89.1
# Testing target stats: mean=95.6, std=96.5

# %%
# Train and evaluate
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(X_train, y_train)

train_preds = model.predict(X_train)
preds = model.predict(X_test)

from helpers import evaluate_model
evaluate_model(y_train, train_preds, y_test, preds)
# Out:
# Training RMSE: 63.56993819459673
# Training R^2: 0.4868930615120072
# Training MAE: 45.86003365603715
# Testing RMSE: 68.95834810705766
# Testing R^2: 0.4852090281226462
# Testing MAE: 49.51246320371384

# %%
print(preds[:5])
print(y_test.head())
# Out:
# [29.62625835 38.20544082 20.38470299  7.838018   13.5001959 ]
# 0    57.6
# 1    26.3
# 2    17.2
# 3    29.3
# 4     0.0
# Name: FantasyPtsPPR_24, dtype: float64

# %%
# Model coefficients
print("Intercept:", model.intercept_)
print("Feature Coefficients:")
for feat, coef in zip(features, model.coef_):
    print(f"{feat}: {coef:.4f}")
# Out:
# Intercept: 79.23543307086612
# Feature Coefficients:
# RushAttPerGame: -10.5874
# RushYdsPerGame: 53.6804
# RushTDsPerGame: -11.8215
# TargetsPerGame: 50.6101
# RecsPerGame: -69.8880
# RecYdsPerGame: 56.9811
# RecTDsPerGame: -5.3094

# %%
from helpers import compute_rank_squared_error, build_results_df

results = build_results_df(y_test, preds, df_23_24_merged['Player'])
rank_squared_error = compute_rank_squared_error(results)

print(results.to_string())
print("Testing Rank Squared Error:", rank_squared_error)
# Out:
#                     Player  Actual   Predicted  ActualRank  PredictedRank  RankError
# 0            Kyle Juszczyk    57.6   29.626258          57             86         29
# 1              Alec Ingold    26.3   38.205441          82             76         -6
# 2           Patrick Ricard    17.2   20.384703          89             95          6
# 3           Michael Burton    29.3    7.838018          76            114         38
# 4         Khari Blasingame     0.0   13.500196         108            101         -7
# 5                 C.J. Ham    13.5   12.310481          90            103         13
# 6            Jakob Johnson     0.0   15.192797         108             99         -9
# 7           Reggie Gilliam     0.7    8.635808         103            113         10
# 8            Adam Prentice     0.0   14.868949         108            100         -8
# 65         Emari Demercado    54.7   69.844670          61             55         -6
# 66         Jamaal Williams    37.1   37.017327          68             78         10
# 67            Jordan Mason   115.0   28.222267          38             88         50
# 68             Chase Brown   255.0   79.880922          10             51         41
# 69           Pierre Strong    35.2   48.611566          71             66         -5
# 70               Cam Akers    93.2   52.650375          45             64         19
# 71         Chris Rodriguez    31.5   33.533945          73             81          8
# 72          Michael Carter    35.8   42.602905          70             72          2
# 73           Kendre Miller    29.1   94.234562          78             42        -36
# 74   Cordarrelle Patterson    37.5   31.360109          67             85         18
# 75             Jeff Wilson    10.6   66.026947          94             59        -35
# 76             Dalvin Cook     4.0   47.108924         100             67        -33
# 77        D'Ernest Johnson    35.9   56.696042          69             63         -6
# 78              Ty Johnson    91.7   44.056447          46             71         25
# 79              Tony Jones    11.5   35.472431          93             79        -14
# 80          Craig Reynolds    20.9   32.135932          86             83         -3
# 81         Darrynton Evans     0.3   68.507760         106             57        -49
# 82          Ameer Abdullah   125.2   46.672903          36             68         32
# 83             Tank Bigsby   129.0   19.268322          34             96         62
# 84              Nick Chubb    63.3  168.313038          55             12        -43
# 85          Patrick Taylor    29.8   49.317716          75             65        -10
# 86             Trey Sermon    53.8   34.560203          62             80         18
# 87           Ronnie Rivers    18.3   32.413585          87             82         -5
# 88           Tyler Goodson    44.4   59.962420          64             61         -3
# 89       Raheem Blackshear     8.0   27.727609          96             89         -7
# 90            Chris Brooks    42.2   28.735255          66             87         21
# 91          Emanuel Wilson    96.0   40.173136          44             74         30
# 92            J.K. Dobbins   191.8   59.299640          23             62         39
# 93         Keaontay Ingram     0.0   26.993122         108             90        -18
# 94           Hunter Luepke    26.9   11.456103          81            104         23
# 95         Dare Ogunbowale    56.0   31.990627          60             84         24
# 96            Deuce Vaughn    11.8   24.597455          92             92          0
# 97       Trayveon Williams     0.0   12.742560         108            102         -6
# 98         Gary Brightwell     0.0   44.501921         108             70        -38
# 99               Eric Gray    17.3   15.415242          88             98         10
# 100        Ke'Shawn Vaughn     0.4   25.539670         105             91        -14
# 101            Sean Tucker    68.7   11.204313          52            106         54
# 102          DeeJay Dallas    21.0   18.444614          85             97         12
# 103     Tyrion Davis-Price     0.7   40.085129         103             75        -28
# 104              Evan Hull     0.0   21.078355         108             94        -14
# 105           Kene Nwangwu     6.0   10.884744          99            108          9
# 106          Jonathan Ward     2.2   11.371768         101            105          4
# 107        Julius Chestnut    13.3    9.008951          91            110         19
# 108           Myles Gaskin     2.0    9.008951         102            110          8
# 109          Jamycal Hasty    28.8   21.812369          79             93         14
# 110           Travis Homer     6.4   11.009485          98            107          9
# 111         Kenny McIntosh    22.4    9.008951          84            110         26
# 112       Jeremy McNichols    63.8    9.008951          54            109         55
# 113            Jordan Mims    26.1   41.017497          83             73        -10
# Testing Rank Squared Error: 64864

# %%
import joblib
import os

model_package = {
    'model': model,
    'scaler': scaler,
    'features': features
}

os.makedirs('models', exist_ok=True)
filepath = os.path.join('models', 'rb_fb_model.joblib')

joblib.dump(model_package, filepath)

print("Model saved as 'rb_fb_model.joblib'")
# Out:
# Model saved as 'rb_fb_model.joblib'
